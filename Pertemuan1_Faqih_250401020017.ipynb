# %% [markdown]
# <a href="https://colab.research.google.com/github/itsfaqih/data-science-2026/blob/main/Pertemuan1_Faqih_250401020017.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
nama = "Muhammad Faqih Muntashir"
angkatan = 2025
ipk = 4
aktif = True

print(f"Nama     : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK      : {ipk}")
print(f"Aktif    : {aktif}")
# Out:
# Nama     : Muhammad Faqih Muntashir
# Angkatan : 2025
# IPK      : 4
# Aktif    : True

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]

print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Muhammad Faqih Muntashir", "Informatika", 2025)
print(hasil)
# Out:
# Hai! Saya Muhammad Faqih Muntashir dari Informatika, angkatan 2025.
